# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("globalterrorism.csv")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.shape
# Out:
# (181691, 135)

# %%
# show all column names on df
print(df.columns.tolist())
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
# column date
# changing 0 to 1 in the month and day columns
df.loc[(df['imonth'] == 0, 'imonth')] = 1
df.loc[(df['iday'] == 0), 'iday'] = 1

# %%
# create new column date based on iyear, imonth and iday column values
df.insert(1, 'date', '')

# %%
from datetime import date
DATE = []
for y,m,d in zip(df.iyear, df.imonth, df.iday):
    DATE.append(date(y,m,d))
    
df['date'] = DATE

df = df.drop(columns = ['iyear','imonth','iday'])

# %%
df.head()
# Out:
#         eventid        date approxdate  extended resolution  country  \
# 0  1.970000e+11  1970-07-02        NaN         0        NaN       58
# 1  1.970000e+11  1970-01-01        NaN         0        NaN      130
# 2  1.970010e+11  1970-01-01        NaN         0        NaN      160
# 3  1.970010e+11  1970-01-01        NaN         0        NaN       78
# 4  1.970010e+11  1970-01-01        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  ...  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN  ...
# 1              Mexico       1                North America   Federal  ...
# 2         Philippines       5               Southeast Asia    Tarlac  ...
# 3              Greece       8               Western Europe    Attica  ...
# 4               Japan       4                    East Asia   Fukouka  ...
#
#   addnotes  scite1  scite2  scite3  dbsource INT_LOG INT_IDEO  INT_MISC  \
# ...

# %%
pd.to_datetime(df['date'], format= '%Y-%m-%d')
# Out:
# 0        1970-07-02
# 1        1970-01-01
# 2        1970-01-01
# 3        1970-01-01
# 4        1970-01-01
#             ...
# 181686   2017-12-31
# 181687   2017-12-31
# 181688   2017-12-31
# 181689   2017-12-31
# 181690   2017-12-31
# Name: date, Length: 181691, dtype: datetime64[ns]

# %%
print(df.columns.tolist())
# Out:
# ['eventid', 'date', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'clai
# ...

# %%
df = df.replace({'Unknown':'', -99.0 : '', -9.0 : ''}, regex=True)

# %%
df.rename(columns={'country_txt':'Country','region_txt':'Region','attacktype1_txt':'Attack_type','target1':'Target',
                   'nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                   'weaptype1_txt':'Weapon_type','success':'Success','motive':'Motive'}, inplace=True)

# %%
new_df = df[['eventid','date','Country','Region','city','latitude','longitude','Attack_type','Killed',
             'Wounded','Target','Summary','Group','Target_type','Weapon_type','Success','Motive']]

# %%
new_df['casualties'] = new_df['Killed'] + new_df['Wounded']
#make new column

# %%
new_df.head()
# Out:
#         eventid        date             Country                       Region  \
# 0  1.970000e+11  1970-07-02  Dominican Republic  Central America & Caribbean
# 1  1.970000e+11  1970-01-01              Mexico                North America
# 2  1.970010e+11  1970-01-01         Philippines               Southeast Asia
# 3  1.970010e+11  1970-01-01              Greece               Western Europe
# 4  1.970010e+11  1970-01-01               Japan                    East Asia
#
#             city   latitude   longitude                     Attack_type  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2                 15.478598  120.599741                   Assassination
# 3         Athens   37.99749   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
new_df.fillna('')
# Out:
#              eventid        date             Country  \
# 0       1.970000e+11  1970-07-02  Dominican Republic
# 1       1.970000e+11  1970-01-01              Mexico
# 2       1.970010e+11  1970-01-01         Philippines
# 3       1.970010e+11  1970-01-01              Greece
# 4       1.970010e+11  1970-01-01               Japan
# ...              ...         ...                 ...
# 181686  2.017120e+11  2017-12-31             Somalia
# 181687  2.017120e+11  2017-12-31               Syria
# 181688  2.017120e+11  2017-12-31         Philippines
# 181689  2.017120e+11  2017-12-31               India
# 181690  2.017120e+11  2017-12-31         Philippines
#
#                              Region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                     North America    Mexico city  19.371887  -99.086624
# 2                    Southeast Asia                 15.478598  120.599741
# ...

# %%
new_df['casualties'].describe()
# Out:
# count    164817.000000
# mean          5.296128
# std          42.069023
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           4.000000
# max        9574.000000
# Name: casualties, dtype: float64

# %%
new_df.to_csv('gtd_clean.csv')

# %%
new_df.shape
# Out:
# (181691, 18)
